# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %%
score = 12
print(type(score))
# Out:
# <class 'int'>

# %%
number = 0

while number < 5:
    number += 1

    if number == 3:
        continue

    print(number)
# Out:
# 1
# 2
# 4
# 5

# %%
for number in range(1, 6):
    if number == 4:
        break
    print(number)
# Out:
# 1
# 2
# 3

# %%
for number in range(1, 6):
    if number == 4:
        continue
    print(number)
# Out:
# 1
# 2
# 3
# 5
